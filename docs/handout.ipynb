# %% [markdown]
# ## **TRAAA - MÔ HÌNH ĐÁNH GIÁ TẮC NGHẼN GIAO THÔNG**

# %% [markdown]
# ### **Xây dựng kiến thức, định hướng nền tảng**
# 1. **Lĩnh vực**
#     - **Thị giác máy tính**(Computer Vision)
#     - **Học sâu** (Deep learning) và **Convolutional Neural Networks (CNN)** : Phân tích đưa ra "đặc trưng".
#     - **YOLO**: Kiến trúc, mô hình một giai đoạn
# 2. **Nền tảng**
#     - Lý thuyết ảnh
#     - Các kỹ thuật xử lý ảnh (Image Processing):
#     - Phương pháp triển khai mô hình, sử dụng các mô hình có sẵn
#     - Đánh giá, xuất dữ liệu

# %% [markdown]
# ### **Hướng thực hiện:**
# **Tuần 1 - 2: Xác định đề tài,cấu trúc mã nguồn, Yolov8**
#
# **Tuần 3 - 4: views, phân tích không gian và mật độ phương tiện**
#
# * **Mục tiêu:** Từ các phương tiện đã được nhận diện, mục tiêu của giai đoạn này là trích xuất hai thông tin chiều sâu quan trọng: **hướng di chuyển tương đối** của từng xe và **mật độ giao thông** tổng thể trong khung hình, xác định vùng đường.
#
# **Tuần 5 - 6: Xây dựng pipeline, hoàn thiện logic đánh giá**
#
# ---

# %% [markdown]
# #### **Lý thuyết cơ bản cần nắm**

# %% [markdown]
# #### **Quy trình xây dựng mô hình, sử dụng các công nghệ**

# %% [markdown]
# ### **Xây dựng định hướng tính toán, phân tích của mô hình**
